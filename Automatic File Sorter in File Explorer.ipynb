# %%
import os,shutil#OS- operating system

# %%
path = r"C:/Users/Hp/OneDrive/Desktop/Documents/"

# %%
file_name=os.listdir(path)

# %%
#checkig if folder exists already
os.path.exists(path="csv files")
# Out:
# False

# %%
folder_name=['image files','pdf files']
for loop in range(0,2):
    if not os.path.exists(path+folder_names[loop]):
        print(path+folder_names[loop])
        os.makedirs(path+folder_names[loop])

# %%
for file in file_name:
    if ".pdf" in file and not os.path.exists(path+"pdf files/"+file):
        shutil.move(path+file,path+"pdf_files/"+file)
    elif ".jpg" in file and not os.path.exists(path+"image files/"+file):
        shutil.move(path+file,path+"image files/"+file)
